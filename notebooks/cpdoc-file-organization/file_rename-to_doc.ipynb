# %% [markdown]
# ### RENAME FILES
# Esta ferramenta renomeia arquivos/imagens referentes a documentos do CPDOC.
#
# Documentos trabalhados: Fundo AAS (Antonio Azeredo da Silveira), Série Ministério das Relações.
#
# O objetivo foi compatibilizar os nomes de todos os arquivos e documentos, de modo a facilitar a correspondência entre todos os arquivos em formato .tif .jpg e .txt, assim como os documentos físicos.
#
# Nota: terei que ver futuramente a questão do arquivo duplicado 'I0042273.TIF'

# %%
import os
import re
from itertools import islice
import shutil
from natsort import natsorted

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
Cria função que lista arquivos por ordem de numero da imagem
Para capturar numero de imagem, fiz split entre 'img' e '\.[Tt]'. O Tt era 
necessario para capturar tanto arquivos .TIF quanto .txt
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
def special_sort(l):
    alphanum_key = lambda key: [ convert(c) for c in re.split('(img|\.[Tt])', key) if c.isdigit() ]
    return sorted(l, key = alphanum_key)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
Captura pastas e arquivos a serem trabalhados, cria lista de nomes de arquivos, organiza em ordem crescente. 
Note que são selecionados apenas arquivos com terminacao .txt
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
path_txt_dossies = 'C:/Users/marcelo.ribeiro/Dropbox/A-Marcelo/Educação-Trabalho/2016-CPDOC/Azeredo Papers/material-renomeacao-arquivos/'
file_aas = 'C:/Users/marcelo.ribeiro/Dropbox/A-Marcelo/Educação-Trabalho/2016-CPDOC/Azeredo Papers/material-renomeacao-arquivos/AAS.txt'

### for images ###
path = 'C:/Users/marcelo.ribeiro/Documents/0-azeredo-imagens/'
path_renamed = 'C:/Users/marcelo.ribeiro/Documents/0-azeredo-imagens-renamed/'
### for txts ###
path = 'C:/Users/marcelo.ribeiro/Documents/textfiles-original-renamed/'
path_renamed = 'C:/Users/marcelo.ribeiro/Documents/textfiles-original-renamed2/'

### here I might choose which type of file I want to work with
#sufix = '.JPG'
#sufix = '.TIF'
sufix = '.txt'

#onlyfiles_txtguide = [f for f in os.listdir(path_txtguide) if f.startswith('AAS') and f.endswith('.txt') and not f.startswith('AAS mre ag 1973.11.20')] 
onlyfiles_txt_dossies = [f for f in os.listdir(path_txt_dossies) if f.startswith('marca AAS mre')] 

dossie_fullpath_list = []
dossie_fullpath = ''
for file_dossie in onlyfiles_txt_dossies:
    dossie_fullpath = path_txt_dossies+file_dossie
    dossie_fullpath_list.append(dossie_fullpath)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
Verifica listagem de pastas e arquivos.
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
dossie_fullpath_list

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
ABRE ARQUIVOS file_dossie QUE POSSUEM ERROS (QUEBRAS DE SEQUENCIA) E CONSERTA OS ERROS
NECESSARIO RODAR ESTE TRECHO SOMENTE UMA VEZ
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
for file_dossie in dossie_fullpath_list:
    if file_dossie == dossie_fullpath_list[0]:
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc VIII-30 - 1687)\n(doc VIII-31 - 1689)',r'\1\ndoc VIII-30 - 1688\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)        
    elif file_dossie == dossie_fullpath_list[6]: 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc V-52 - 1554)\n(doc V-53 - 1559)',r'\1\ndoc V-52 - 1555\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie == dossie_fullpath_list[11]: 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc 4 - 36)\n(doc 5 - 74)',r'\1\ndoc 4 - 54\ndoc 4 - 55\n\2',texto)
            texto = re.sub('Anexo ao Dossiê - 82',r'doc 7 - 82',texto) # nao eh o nome correto. Corrigir depois.
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie == dossie_fullpath_list[35]: 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc I-14 - 57)\n(doc I-15 - 63)',r'\1\ndoc I-14 - 61\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre onu 1974.03.12.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc II-A8 - 1199)\n(doc III-1 - 1270)',r'\1\ndoc II-A8 - 1219\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre onu 1975.01.23.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc II-1 - 183)\n(Capa - 413)',r'\1\ndoc II-1 - 208\ndoc II-1 - 223\ndoc II-1 - 278\ndoc II-1 - 279\n\2',texto)
            texto = re.sub('(doc III-7 - 780)\n(Capa - 849)',r'\1\ndoc III-7 - 815\n\2', texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre onu 1976.08.25.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc II-1 - 133)\ndoc II-1 - 187',r'\1\n',texto)
            texto = re.sub('(doc II-1 - 133)\n',r'\1\ndoc II-1 - 187',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre onu 1977.03.04.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc II-1 - 55)\n.*\n.*\n.*\n.*',r'\1\n',texto)
            texto = re.sub('(doc II-1 - 55)\n',r'\1\ndoc II-1 - 126\ndoc II-1 - 127\ndoc II-1 - 147\ndoc II-1 - 148',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre vm 1974.06.13.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('Capa - 160',r'doc II-1 - 160',texto)
            texto = re.sub('Capa - 1338',r'doc VI-1 - 1338',texto)
            texto = re.sub('Capa - 1815',r'doc VII-1 - 1815',texto)
            texto = re.sub('(doc VIII-1 - 2198)\n(doc VIII-2 - 2258)',r'\1\ndoc VIII-1 - 2222\n\2',texto)
            texto = re.sub('(doc VIII-7 - 2330)\n(doc VIII-8 - 2362)',r'\1\ndoc VIII-7 - 2351\n\2',texto)
            texto = re.sub('(doc XVI-1 - 5381)\n(doc XVI-2 - 5502)',r'\1\ndoc XVI - 1 - 5382\ndoc XVI - 1 - 5474\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre vp 1975.09.03.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc III-16 - 386)\ndoc III-16 - 451',r'\1\n',texto)
            texto = re.sub('(doc III-16 - 386)\n',r'\1\ndoc III-16 - 451',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    elif file_dossie.endswith('marca AAS mre vp 1976.03.30.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc 6 - 35)\n(doc 7 - 40)',r'\1\ndoc 6 - 36\ndoc 6 - 37\ndoc 6 - 38\n\2',texto)
            texto = re.sub('(doc 10 - 56)\n(doc 12 - 188)',r'\1\ndoc 10 - 57\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)
    if file_dossie.endswith('marca AAS mre vp 1978.01.12.txt'): 
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto = re.sub('(doc 20 - 76)\n(doc 21 - 91)',r'\1\ndoc 20 - 82\n\2',texto)
        with open(file_dossie, 'w') as f_dossie:
            txt = f_dossie.write(texto)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
Modifica nomes de arquivos: Cria prefixos, identifica arquivos correspondentes, 
modifica nomes.

prefix1 = fundo e serie: AAS / mre
prefix2 = subserie e dossie. Exemplo: ag / 1974.03.13
prefix3 = documento. Exemplo: doc I-1
num_imagem = numero da imagem. Exemplo: 0049374
sufix = terminacao do arquivo. Exemplo .txt , .jpg ou .tif
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''

prefix1 = 'AAS_mre_'
prefix3_list = []
doc_start_list = []
f_aas_list = []
doc_range_list = []
file_new_list = []
dossie_start_list = []
prefix2_list = []
dossie_range_list = []
num_imagem_list = []
dossie_start = 0
num_imagem = 0
dossie_subgroups = 0

'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
ABRE ARQUIVO file_aas, QUE CONTEM DIVERSAS INFORMACOES SOBRE DOSSIES, TAL COMO:
NUMERO DE PAGINAS DE CADA DOSSIE E NUMERO DE IMAGENS QUE CORRESPONDE AO INICIO E FIM DO DOSSIE.
SEPARA INFO DO ARQUIVO EM UMA LISTA.
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
with open(file_aas, 'r') as f_aas: # iterates on lines
    for line in f_aas:
        line = line.strip()
        f_aas_list.append(line) 
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
CRIA prefix2, dossie_range (numero de paginas de cada dossie +1)
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
count = -1
for line in f_aas_list:
    count += 1
    if not line.startswith('AAS mre') and not line.startswith('1974.'):
        continue
    dossie_numbers = f_aas_list[count+1] 
    dossie_numbers = re.sub('(.*);',r'\1',dossie_numbers)
    dossie_numbers = dossie_numbers.split(';')
    for number in dossie_numbers:
        dossie_start = int(re.sub('(.*)-.*',r'\1',number)) 
        dossie_start_list.append(dossie_start) 
        dossie_end = int(re.sub('.*-(.*)',r'\1',number))
        dossie_range = dossie_end - dossie_start + 1
        dossie_range_list.append(dossie_range) #new 08-09
        prefix2 = re.sub('.* .* ([a-z]{1,3}) +([\d\.]+)(/?\d*).*',r'\1_\2\3_',line) 
        prefix2 = re.sub('\/',r'-',prefix2) 
        prefix2_list.append(prefix2) 
        dossie_subgroups += 1
    #dossie_range = int(re.sub('.*;(\d+);',r'\1',line))+1

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
Lista e reescreve dossiês com sequenciamento distinto e problemático
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
dossie_alt_list = ['AAS mre d 1974.03.26.txt', 'AAS mre d 1974.04.23.txt', 'AAS mre onu 1974.03.12.txt', 
                   'AAS mre onu 1975.01.23.txt', 'AAS mre onu 1976.08.25.txt', 'AAS mre onu 1977.03.04.txt',
                   'AAS mre onu 1978.05.11.txt', 'AAS mre pn 1974.08.15.txt', 'AAS mre pn 1974.09.11.txt', 
                   'AAS mre pn 1975.00.00.txt', 'AAS mre pn 1975.04.25.txt', 'AAS mre pn 1975.09.25.txt', 
                   'AAS mre pn 1976.12.28.txt', 'AAS mre rb 1974.04.20.txt', 'AAS mre vm 1974.06.13.txt', 
                   'AAS mre vp 1975.09.03.txt', 'AAS mre vp 1976.03.30.txt', 'AAS mre vp 1977.10.31.txt', 
                   'AAS mre vp 1978.01.12.txt']
dossie_ok_list = ['AAS mre onu 1975.02.18.txt', 'AAS mre onu 1978.11.01.txt', 'AAS mre rb 1974.02.06.txt', 
                  'AAS mre rb 1974.02.18.txt', 'AAS mre rb 1974.03.18.txt', 'AAS mre rb 1974.03.19.txt', 
                  'AAS mre rb 1974.03.25.txt', 'AAS mre rb 1974.04.08.txt', 'AAS mre rb 1974.04.14.txt', 
                  'AAS mre rb 1974.04.17.txt', 'AAS mre rb 1974.05.07.txt', 'AAS mre rb 1974.05.23.txt', 'AAS mre rb 1974.07.02.txt', 
                  'AAS mre rb 1974.08.19.txt', 'AAS mre rb 1974.08.27.txt', 'AAS mre rb 1974.10.00.txt', 'AAS mre rb 1974.10.24.txt', 
                  'AAS mre rb 1974.10.25.txt', 'AAS mre rb 1974.12.13.txt', 'AAS mre rb 1974.12.24.txt', 'AAS mre rm 1975.00.00.txt', 
                  'AAS mre rm 1975.03.15.txt']
texto_list = []
for file_dossie in dossie_fullpath_list:
    file_check = re.sub('.*(AAS mre.*)', r'\1', file_dossie)
    if file_check in dossie_alt_list:
        with open(file_dossie, 'r') as f_dossie:
            texto = f_dossie.read()
            texto_list.append(texto)
print(len(texto_list))
sequence_errors_list = []
count = 0
count_dossie = 41
count_texto = -1
for file_dossie in dossie_fullpath_list:
    file_check = re.sub('.*(AAS mre.*)', r'\1', file_dossie)
    if file_check in dossie_ok_list:
        #print('not alt file', file_check)
        count_dossie += 1
    if file_check in dossie_alt_list:
        #print('file_check',file_check)
        reset_counter = 0
        if file_check != dossie_alt_list[0]: count_dossie += 1 # avança na lista a partir do segundo arquivo
        count_texto += 1
        #print('count_texto', count_texto, 'count_dossie', count_dossie)
        texto = texto_list[count_texto]
        if file_check == 'marca AAS mre onu 1974.03.12.txt': print('texto checker', texto)
        with open(file_dossie, 'r') as f_dossie:
            for line in f_dossie:
                #print(line)
                line = line.strip()
                if line.startswith('doc '):
                    doc_start = int(re.sub('.* - (.*)',r'\1',line)) - reset_counter
                    #print(line)
                    if doc_start <= dossie_range_list[count_dossie] and dossie_range_list[count_dossie] != 1: #normal dossie
                        print('doc_start', doc_start, 'dossie_range_list', dossie_range_list[count_dossie])
                    elif doc_start > dossie_range_list[count_dossie] or dossie_range_list[count_dossie] == 1: #'broken dossie'
                        #print('broken doc_start', doc_start, 'dossie_range_list', dossie_range_list[count_dossie], 'dossie_start_list', dossie_start_list[count_dossie])
                        #print('at', f_dossie)
                        reset_counter += dossie_range_list[count_dossie]
                        doc_start = doc_start - dossie_range_list[count_dossie]
                        if doc_start == 0: doc_start = 1 #codigo bugado! estou zerando o start em alguns casos
                        if doc_start != 1:
                            new_number_fix = dossie_range_list[count_dossie]
                            count_dossie += 1
                            reset_counter += dossie_range_list[count_dossie]
                            doc_start = doc_start - dossie_range_list[count_dossie]
                            #print('Fix process BROKEN')
                            line_add_prefix = re.sub('(doc .+-.+ - |doc .+ - )\d+', r'\1', previous_line)
                            line_add_sufix = str(int(re.sub('(doc .+-.+ - |doc .+ - )(\d+)', r'\2', previous_line)) + new_number_fix)
                            new_line = line_add_prefix + line_add_sufix
                            text_change = previous_line+'\n'+new_line
                            texto = re.sub(previous_line,text_change,texto)
                            with open(file_dossie, 'w') as f_dossie:
                               txt = f_dossie.write(texto) 
                            sequence_error = file_check, new_line
                            #print('sequence_error',sequence_error)
                            sequence_errors_list.append(sequence_error)
                        #print ('fixed broken doc_start',doc_start, 'reset_counter',reset_counter)
                        count_dossie += 1
                        previous_line = line

# %% [raw]
# print(texto)
# print('sequence_errors_list', sequence_errors_list)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
ABRE ARQUIVOS file_dossie, QUE CONTEM INFO SOBRE CADA DOSSIE ESPECIFICO.
CRIA LISTA DE MARCACOES DE NUMERO DE IMAGEM QUE EQUIVALE AO INICIO DO DOCUMENTO
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
count = -1
count_dossie = -1
sequence_break = 0


for file_dossie in dossie_fullpath_list:
    count_dossie += 1
    #print('1',file_dossie)

    reset_counter = 0
    #count += 1
    with open(file_dossie, 'r') as f_dossie: # iterates on lines

        for line in f_dossie:
            line = line.strip()
            if line.startswith('doc '):
                doc_start = int(re.sub('.* - (.*)',r'\1',line)) - reset_counter
                if doc_start <= dossie_range_list[count_dossie] and dossie_range_list[count_dossie] != 1: #normal dossie
                    doc_start_list.append(doc_start)
                    #print('doc_start', doc_start, 'dossie_range_list', dossie_range_list[count_dossie])
                    #print('broken dossie NOT detected')
                elif doc_start > dossie_range_list[count_dossie] or dossie_range_list[count_dossie] == 1: #'broken dossie'
                    #print('BROKEN dossie detected')
                    #print('broken doc_start',doc_start, 'dossie_range_list', dossie_range_list[count_dossie], 'dossie_start_list', dossie_start_list[count_dossie], 'at', f_dossie)
                    #print('count_dossie', count_dossie)
                    reset_counter += dossie_range_list[count_dossie]
                    doc_start = doc_start - dossie_range_list[count_dossie]
                    if doc_start == 0: doc_start = 1 #codigo bugado! estou zerando o start em alguns casos
                    #print ('fixed broken doc_start',doc_start, 'reset_counter',reset_counter)
                    doc_start_list.append(int(doc_start))
                    count_dossie += 1

                    
doc_start_list.append(1) # necessario, pois o numero posterior eh usado como referencia


'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
CRIA prefix3.
CRIA LISTA DE NUMERO DE PAGINAS DE CADA DOCUMENTO.
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
count = -1
count_dossie = 0
for file_dossie in dossie_fullpath_list:
    with open(file_dossie, 'r') as f_dossie: # iterates on lines
        for line in f_dossie:
            line = line.strip()
            if line.startswith('doc '):
                print(file_dossie, line)
                count += 1
                prefix3 = re.sub('doc (.*) - .*',r'doc_\1_',line)
                prefix3_list.append(prefix3)
                doc_start = re.sub('.* - (.*)',r'\1',line)
                #print(doc_start)
                print('dossie_range_list', dossie_range_list[count_dossie])
                print('doc_start_list[count+1]', doc_start_list[count+1], 'doc_start_list[count]', doc_start_list[count])
                if doc_start_list[count+1] == 2 and doc_start_list[count] != 1: # arquivo atípico começa em 2
                    doc_end = dossie_range_list[count_dossie]
                    doc_range = int(doc_end) - int(doc_start_list[count]) + 1
                    doc_range_list.append(doc_range)
                    print('doc_start',doc_start_list[count])
                    print('doc_end',doc_end)
                    print('dossie ends at number', count_dossie, ', range:',dossie_range_list[count_dossie])
                    count_dossie += 1
                    print('broken dossie ends')
                if doc_start_list[count+1] != 1:
                    if file_dossie.endswith('rm 1975.03.15.txt') and doc_start_list[count] == 146: continue# arquivo começa em 2
                    doc_end = int(doc_start_list[count+1])-1
                    doc_range = int(doc_end) - int(doc_start_list[count]) + 1
                    doc_range_list.append(doc_range)
                    print('doc_start',doc_start_list[count])
                    print('end:', doc_end, 'start:', doc_start)
                    print('dossie ends at number', count_dossie, ', range:',dossie_range_list[count_dossie])
                    print('doc_range',doc_range)
                    print('dossie continues')
                if doc_start_list[count+1] == 1:
                    doc_end = dossie_range_list[count_dossie]
                    doc_range = int(doc_end) - int(doc_start_list[count]) + 1
                    doc_range_list.append(doc_range)
                    print('doc_start',doc_start_list[count])
                    print('doc_end',doc_end)
                    print('dossie ends at number', count_dossie, ', range:',dossie_range_list[count_dossie])
                    count_dossie += 1
                    print('normal dossie ends')
print('doc_range_list is: ',doc_range_list)


'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
CRIA NOME DOS ARQUIVOS, DE MODO QUE CORRESPONDA A CADA PAGINA DE DOCUMENTO, 
MAS PRESERVANDO SUA CORRESPONDENCIA COM CADA IMAGEM.
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
dossie_count = -1
dossie_line_count = -1
doc_end = 0
doc_count = -1
doc_number = -1   
count = -1
file_list = []
imagem_errors = [38819, 38913, 39201, 39217, 39809, 40071, 40161, 40712, 40820, 42362, 46837, 65086, 65179]
imagem_errors2 = ['46908', '46910','46912', '46913', '46916','46918','46920','46922']

for doc_range in doc_range_list:
    count += 1
    doc_number += 1
    print('start', doc_start_list[count], 'last start', doc_start_list[count-1])
    if doc_start_list[count] == 1 or doc_start_list[count] == 2 and doc_start_list[count-1] != 1:
        dossie_count += 1
        doc_count = -1 # reseta doc_count
        if doc_start_list[count] == 2 and doc_start_list[count-1] != 1:
            doc_count = 0
    prefix2 = prefix2_list[dossie_count]
    prefix3 = prefix3_list[doc_number]
    dossie_start = dossie_start_list[dossie_count]
    pagina = 0
    print('prefix2 is',prefix2, 'doc_range', doc_range)
    print('prefix3 is',prefix3)
    for i in range(doc_range):
        pagina += 1
        doc_count += 1
        print('doc_count', doc_count)
        num_imagem = dossie_start+doc_count
        test_error = num_imagem+1
        if test_error in imagem_errors: doc_count += 1
        num_imagem_list.append(num_imagem) # append o int para trabalhar com arquivos depois
        num_imagem = str(num_imagem).zfill(5)
        print('num_imagem', num_imagem)
        file_new = prefix1 + prefix2 + prefix3 + 'pag' + str(pagina) + '_img' + str(num_imagem) + sufix
        if num_imagem not in imagem_errors2:
            file_list.append(file_new)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
ACRESCENTA IMAGENS DE CAPAS DE SUBSSERIES E SERIE
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
serie_subsseries_erros = ['AAS_mre_img34042.txt', 'AAS_mre_ag_img34041.txt', 'AAS_mre_ai_img34030.txt', 
                          'AAS_mre_be_img34032.txt', 'AAS_mre_bp_img34033.txt', 'AAS_mre_d_img34034.txt', 
                          'AAS_mre_onu_img34035.txt', 'AAS_mre_pn_img34036.txt', 'AAS_mre_rb_img34037.txt', 
                          'AAS_mre_rm_img34038.txt', 'AAS_mre_vm_img34039.txt', 'AAS_mre_vp_img34040.txt', 
                          'AAS_mre_vm_1974.06.13_doc_I-1_img06375.txt']
file_new_list = file_list + serie_subsseries_erros

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
ORGANIZA ARQUIVOS EM ORDEM CRESCENTE DO NUMERO DA IMAGEM
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
file_new_list = special_sort(file_new_list)

# %%
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
renomeia arquivos em nova pasta
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
if not os.path.exists(path_renamed):
    os.makedirs(path_renamed)
count = -1

for root, dirs, files in os.walk(path):
    for file in files:
        if not file.endswith(sufix): continue
        if file.endswith('I0042273.TIF'): continue # arquivo duplicado, com terminacao errada
        file_number = int(re.sub('\D*([\d]+).*',r'\1',file))
        count += 1
        file_old = str('{}/{}'.format(root, file))
        file_old = file_old.replace('\\','/')
        #print('old', file_old)
        file_new = path_renamed+file_new_list[count]
        #print('new', file_new)
        shutil.copy2(file_old, file_new)

# %% [markdown]
# ### RASCUNHOS

# %% [raw]
# '''
# USING REVERSED
# '''
# prefix1 = 'AAS_mre_'
# #prefix3list = []
# doc_start = 0
#
# f_aas = open(file_aas, 'r')
# #with open(file_aas, 'r') as f_aas: # iterates on lines
# #    for line in f_aas:
# #        print(line)
# f_aas = reversed(list(open(file_aas, 'r')))
# for line in f_aas:
#     print(line)
